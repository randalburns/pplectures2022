# %% [markdown]
# ### Exercise 9: Communicating Ray Actors (solutions code at bottom)
#
# This is a short exercise to demonstrate how actors can communicate through remote oids.
# We are going to break the actors of the ImageNet classification [Example XX](RayImageNet.ipynb) into
# two actors: one that transforms the image into an ResNet50 compatible tensor and one that takes
# the tensor as input and returns the classification.
#
# You have been given two class files that have been written to be instantiated as Ray actors:
#   * [rayresnet50_normalize](../rayresnet50_normalize.py)
#   * [rayresnet50_classify](../rayresnet50_classify.py)
#
# To complete the exercise you need to populate the following driver code.  Then answer the questions.
#
# Data is from https://github.com/EliSchwartz/imagenet-sample-images.
#
# Note: check your ouput to make sure that the predictions match the input file. This classifier should be over 90% correct. You need to be careful to match the return OIDs with files. **Include the cell output in submitted notebook**.

# %%
from rayresnet50_normalize import RRN50Normalize
from rayresnet50_classify import RRN50Classify
import ray
import time
import os

num_actors=4

# script to drive parallel program
ray.init(num_cpus=num_actors, ignore_reinit_error=True)

### TODO instantiate 4 normalization actors

### TODO instantiate 4 classification actors


directory = '../data/imagenet1000'
files = os.listdir(directory)

start_time = time.time()  # Get the current time

for i in range(len(files)):
    if files[i].endswith(".JPEG"):
        file_path = os.path.join(directory, files[i])

        ### TODO call remote to normalize image into tensor
        
        ### TODO call remote to classify tensor
        
        ### TODO store the oids needed to complete the computation
        
for i in range(len(files)):
    try:
        ### TODO collect results for each file in a variable preds
        # preds = ray.get(....)
        # print(f"Filename {files[i]}: predictions {preds}")
    except:
        pass

end_time = time.time()  # Get the current time again

execution_time = end_time - start_time
print("Execution time: ", execution_time, " seconds")

# %% [markdown]
# ### Questions
#
# Answer these questions inline in this markdown cell.
#
# * Question 1: Does the computation for a single input file (normalization and classification) run in serial or parallel?  If serially, how is the dependency enforced?
#
# Serial. Classification blocks waits on OID of normalization.
#
# * Question 2: Does the computation of different files run in serial or parallel?  If parallel, explain why they are independent.
#
# Parallel. Launched independently all at the same time.
#
# * Question 3: Your computation needs to collect return identifiers for the classification objects. It is not necessary to collect the OIDs of the normalization function in the driver code. Why?
#
# The normalization oids are passed to the classification functions. Only need classification oids to get returns.
#
# * Question 4: At any given point in time, how many actors are running and what are they doing?
#
# 8 actors. 4 classification. 4 normalization.
#
# * Question 5: Is this implementation faster or slower than doing the same work in one actor?  Can you think of a situation in which it would be faster to decompose the code?  (By situation, I mean data properties or target hardware system on which this would be prefereable.)
#
# Faster if you had different hardware, e.g. GPU for classification.  Other ideas OK.

# %%
from rayresnet50_normalize import RRN50Normalize
from rayresnet50_classify import RRN50Classify
import ray
import time
import os

num_actors=4

# script to drive parallel program
ray.init(num_cpus=num_actors, ignore_reinit_error=True)

normactors = []
for i in range(num_actors):
    normactors.append(RRN50Normalize.remote())
    
classactors = []
for i in range(num_actors):
    classactors.append(RRN50Classify.remote())    

current_actor = 0


directory = '../data/imagenet1000'
files = os.listdir(directory)
croids = [None] * len(files)

start_time = time.time()  # Get the current time

for i in range(len(files)):
    if files[i].endswith(".JPEG"):
        file_path = os.path.join(directory, files[i])
        nroid = normactors[i%num_actors].normalize_image.remote(file_path)
        # why doesn't the driver need to collect the nroid?
        croids[i] = classactors[i%num_actors].classify_image.remote(nroid)
        
for i in range(len(files)):
    try:
        preds = ray.get(croids[i])
        print(f"Filename {files[i]}: predictions {preds}")
    except:
        pass

end_time = time.time()  # Get the current time again

execution_time = end_time - start_time
print("Execution time: ", execution_time, " seconds")
# Out:
# 2023-06-21 14:17:55,763	WARNING services.py:1826 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67108864 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=0.41gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2023-06-21 14:17:55,901	INFO worker.py:1636 -- Started a local Ray instance.
# Filename n01443537_goldfish.JPEG: predictions ['goldfish', 'tench', 'anemone fish']
# Filename n01484850_great_white_shark.JPEG: predictions ['great white shark', 'tiger shark', 'gorilla']
# Filename n01491361_tiger_shark.JPEG: predictions ['tiger shark', 'great white shark', 'hammerhead']
# Filename n01496331_electric_ray.JPEG: predictions ['electric ray', 'stingray', 'clog']
# Filename n01498041_stingray.JPEG: predictions ['electric ray', 'stingray', 'flatworm']
# Filename n01514668_cock.JPEG: predictions ['drake', 'cock', 'hen']
# Filename n01518878_ostrich.JPEG: predictions ['ostrich', 'traffic light', 'water tower']
# Filename n01530575_brambling.JPEG: predictions ['brambling', 'junco', 'coucal']
# Filename n01531178_goldfinch.JPEG: predictions ['goldfinch', 'indigo bunting', 'brambling']
# Filename n01534433_junco.JPEG: predictions ['junco', 'robin', 'bulbul']
# Filename n01537544_indigo_bunting.JPEG: predictions ['indigo bunting', 'goldfinch', 'brambling']
# Filename n01558993_robin.JPEG: predictions ['robin', 'cello', 'worm fence']
# Filename n01580077_jay.JPEG: predictions ['jay', 'corn', 'lynx']
# Filename n01582220_magpie.JPEG: predictions ['magpie', 'black grouse', 'Kerry blue terrier']
# Filename n01592084_chickadee.JPEG: predictions ['chickadee', 'minibus', 'moving van']
# Filename n01608432_kite.JPEG: predictions ['vase', 'goblet', 'spoonbill']
# Filename n01614925_bald_eagle.JPEG: predictions ['bald eagle', 'kite', 'vulture']
# Filename n01616318_vulture.JPEG: predictions ['vulture', 'church', 'white stork']
# Filename n01629819_European_fire_salamander.JPEG: predictions ['European fire salamander', 'spotted salamander', 'common newt']
# Filename n01630670_common_newt.JPEG: predictions ['common newt', 'eft', 'tailed frog']
# Filename n01631663_eft.JPEG: predictions ['eft', 'common newt', 'marmot']
# Filename n01632777_axolotl.JPEG: predictions ['common newt', 'eft', 'thunder snake']
# Filename n01641577_bullfrog.JPEG: predictions ['bullfrog', 'water snake', 'tailed frog']
# Filename n01644373_tree_frog.JPEG: predictions ['tree frog', 'tailed frog', 'banded gecko']
# Filename n01664065_loggerhead.JPEG: predictions ['loggerhead', 'leatherback turtle', 'rock crab']
# Filename n01665541_leatherback_turtle.JPEG: predictions ['leatherback turtle', 'terrapin', 'loggerhead']
# Filename n01667114_mud_turtle.JPEG: predictions ['mud turtle', 'terrapin', 'box turtle']
# Filename n01669191_box_turtle.JPEG: predictions ['box turtle', 'terrapin', 'mud turtle']
# Filename n01675722_banded_gecko.JPEG: predictions ['banded gecko', 'whiptail', 'alligator lizard']
# Filename n01677366_common_iguana.JPEG: predictions ['common iguana', 'green lizard', 'whiptail']
# Filename n01685808_whiptail.JPEG: predictions ['whiptail', 'alligator lizard', 'Gila monster']
# Filename n01687978_agama.JPEG: predictions ['agama', 'whiptail', 'frilled lizard']
# Filename n01688243_frilled_lizard.JPEG: predictions ['frilled lizard', 'whiptail', 'agama']
# Filename n01692333_Gila_monster.JPEG: predictions ['Gila monster', 'Komodo dragon', 'banded gecko']
# Filename n01693334_green_lizard.JPEG: predictions ['American chameleon', 'green lizard', 'alligator lizard']
# Filename n01694178_African_chameleon.JPEG: predictions ['African chameleon', 'banded gecko', 'green lizard']
# Filename n01697457_African_crocodile.JPEG: predictions ['African crocodile', 'American alligator', 'alligator lizard']
# Filename n01698640_American_alligator.JPEG: predictions ['American alligator', 'African crocodile', 'stingray']
# Filename n01704323_triceratops.JPEG: predictions ['triceratops', 'isopod', 'banded gecko']
# Filename n01728920_ringneck_snake.JPEG: predictions ['ringneck snake', 'thunder snake', 'hognose snake']
# Filename n01729322_hognose_snake.JPEG: predictions ['hognose snake', 'horned viper', 'boa constrictor']
# Filename n01729977_green_snake.JPEG: predictions ['green mamba', 'green snake', 'night snake']
# Filename n01735189_garter_snake.JPEG: predictions ['garter snake', 'night snake', 'sidewinder']
# Filename n01737021_water_snake.JPEG: predictions ['drake', 'goose', 'lakeside']
# Filename n01739381_vine_snake.JPEG: predictions ['vine snake', 'green snake', 'night snake']
# Filename n01742172_boa_constrictor.JPEG: predictions ['boa constrictor', 'agama', 'night snake']
# Filename n01744401_rock_python.JPEG: predictions ['rock python', 'boa constrictor', 'night snake']
# Filename n01748264_Indian_cobra.JPEG: predictions ['Indian cobra', 'vase', 'horned viper']
# Filename n01751748_sea_snake.JPEG: predictions ['sea snake', 'eel', 'gar']
# Filename n01753488_horned_viper.JPEG: predictions ['thunder snake', 'night snake', 'horned viper']
# Filename n01755581_diamondback.JPEG: predictions ['diamondback', 'hognose snake', 'sidewinder']
# Filename n01768244_trilobite.JPEG: predictions ['trilobite', 'caldron', 'teapot']
# Filename n01770081_harvestman.JPEG: predictions ['harvestman', 'spider web', 'walking stick']
# Filename n01770393_scorpion.JPEG: predictions ['scorpion', 'isopod', 'crayfish']
# Filename n01773549_barn_spider.JPEG: predictions ['bustard', 'jay', 'peacock']
# Filename n01773797_garden_spider.JPEG: predictions ['garden spider', 'black and gold garden spider', 'spider web']
# Filename n01774384_black_widow.JPEG: predictions ['black widow', 'barn spider', 'garden spider']
# Filename n01775062_wolf_spider.JPEG: predictions ['wolf spider', 'tarantula', 'barn spider']
# Filename n01776313_tick.JPEG: predictions ['tick', 'garden spider', 'paper towel']
# Filename n01784675_centipede.JPEG: predictions ['centipede', 'drum', 'drumstick']
# Filename n01796340_ptarmigan.JPEG: predictions ['ptarmigan', 'partridge', 'ruffed grouse']
# Filename n01797886_ruffed_grouse.JPEG: predictions ['ruffed grouse', 'partridge', 'black grouse']
# Filename n01798484_prairie_chicken.JPEG: predictions ['prairie chicken', 'ptarmigan', 'black grouse']
# Filename n01806567_quail.JPEG: predictions ['quail', 'ruffed grouse', 'partridge']
# Filename n01807496_partridge.JPEG: predictions ['partridge', 'ruffed grouse', 'quail']
# Filename n01817953_African_grey.JPEG: predictions ['African grey', 'macaw', 'sulphur-crested cockatoo']
# Filename n01819313_sulphur-crested_cockatoo.JPEG: predictions ['sulphur-crested cockatoo', 'macaw', 'albatross']
# Filename n01820546_lorikeet.JPEG: predictions ['lorikeet', 'sulphur-crested cockatoo', 'Bedlington terrier']
# Filename n01824575_coucal.JPEG: predictions ['coucal', 'bulbul', 'kite']
# Filename n01829413_hornbill.JPEG: predictions ['hornbill', 'toucan', 'soccer ball']
# Filename n01833805_hummingbird.JPEG: predictions ['hummingbird', 'bucket', 'jacamar']
# Filename n01843065_jacamar.JPEG: predictions ['jacamar', 'bee eater', 'hummingbird']
# Filename n01847000_drake.JPEG: predictions ['drake', 'tiger beetle', 'American coot']
# Filename n01855032_red-breasted_merganser.JPEG: predictions ['red-breasted merganser', 'pelican', 'goose']
# Filename n01855672_goose.JPEG: predictions ['goose', 'drake', 'crane bird']
# Filename n01871265_tusker.JPEG: predictions ['tusker', 'Indian elephant', 'African elephant']
# Filename n01872401_echidna.JPEG: predictions ['echidna', 'porcupine', 'platypus']
# Filename n01873310_platypus.JPEG: predictions ['platypus', 'killer whale', 'beaver']
# Filename n01882714_koala.JPEG: predictions ['koala', 'wombat', 'indri']
# Filename n01883070_wombat.JPEG: predictions ['wombat', 'wood rabbit', 'Angora']
# Filename n01910747_jellyfish.JPEG: predictions ['television', 'monitor', 'desktop computer']
# Filename n01917289_brain_coral.JPEG: predictions ['brain coral', 'eel', 'coral reef']
# Filename n01924916_flatworm.JPEG: predictions ['flatworm', 'sea slug', 'hermit crab']
# Filename n01930112_nematode.JPEG: predictions ['nematode', 'ladle', 'modem']
# Filename n01944390_snail.JPEG: predictions ['snail', 'hermit crab', 'conch']
# Filename n01945685_slug.JPEG: predictions ['slug', 'snail', 'window screen']
# Filename n01950731_sea_slug.JPEG: predictions ['sea slug', 'puffer', 'flatworm']
# Filename n01968897_chambered_nautilus.JPEG: predictions ['chambered nautilus', 'coil', 'butternut squash']
# Filename n01978287_Dungeness_crab.JPEG: predictions ['fiddler crab', 'wild boar', 'crayfish']
# Filename n01978455_rock_crab.JPEG: predictions ['rock crab', 'fiddler crab', 'Dungeness crab']
# Filename n01981276_king_crab.JPEG: predictions ['king crab', 'starfish', 'miniature schnauzer']
# Filename n01983481_American_lobster.JPEG: predictions ['American lobster', 'crayfish', 'spiny lobster']
# Filename n01984695_spiny_lobster.JPEG: predictions ['spiny lobster', 'crayfish', 'American lobster']
# Filename n01986214_hermit_crab.JPEG: predictions ['hermit crab', 'tailed frog', 'fiddler crab']
# Filename n01990800_isopod.JPEG: predictions ['isopod', 'trilobite', 'nematode']
# Filename n02002556_white_stork.JPEG: predictions ['white stork', 'black stork', 'bald eagle']
# Filename n02006656_spoonbill.JPEG: predictions ['spoonbill', 'bee eater', 'flamingo']
# Filename n02007558_flamingo.JPEG: predictions ['flamingo', 'goldfish', 'black swan']
# Filename n02009229_little_blue_heron.JPEG: predictions ['little blue heron', 'bittern', 'crane bird']
# Filename n02011460_bittern.JPEG: predictions ['bittern', 'bustard', 'snail']
# Filename n02012849_crane.JPEG: predictions ['crane bird', 'little blue heron', 'American egret']
# Filename n02013706_limpkin.JPEG: predictions ['limpkin', 'redshank', 'ringlet']
# Filename n02018207_American_coot.JPEG: predictions ['American coot', 'European gallinule', 'terrapin']
# Filename n02018795_bustard.JPEG: predictions ['bustard', 'sliding door', 'redshank']
# Filename n02025239_ruddy_turnstone.JPEG: predictions ['ruddy turnstone', 'entertainment center', 'fiddler crab']
# Filename n02028035_redshank.JPEG: predictions ['redshank', 'dowitcher', 'red-backed sandpiper']
# Filename n02033041_dowitcher.JPEG: predictions ['dowitcher', 'red-backed sandpiper', 'harvestman']
# Filename n02037110_oystercatcher.JPEG: predictions ['oystercatcher', 'albatross', 'ruddy turnstone']
# Filename n02056570_king_penguin.JPEG: predictions ['king penguin', 'sea lion', 'ice bear']
# Filename n02058221_albatross.JPEG: predictions ['albatross', 'sulphur-crested cockatoo', 'toilet tissue']
# Filename n02066245_grey_whale.JPEG: predictions ['grey whale', 'abaya', 'bannister']
# Filename n02074367_dugong.JPEG: predictions ['dugong', 'Band Aid', 'hard disc']
# Filename n02077923_sea_lion.JPEG: predictions ['sea lion', 'sandbar', 'geyser']
# Filename n02085620_Chihuahua.JPEG: predictions ['Chihuahua', 'toy terrier', 'miniature pinscher']
# Filename n02085936_Maltese_dog.JPEG: predictions ['Maltese dog', 'Lhasa', 'Japanese spaniel']
# Filename n02086079_Pekinese.JPEG: predictions ['Pekinese', 'Japanese spaniel', 'Shih-Tzu']
# Filename n02086240_Shih-Tzu.JPEG: predictions ['Shih-Tzu', 'Lhasa', 'Pekinese']
# Filename n02086910_papillon.JPEG: predictions ['papillon', 'Chihuahua', 'Japanese spaniel']
# Filename n02087046_toy_terrier.JPEG: predictions ['miniature pinscher', 'toy terrier', 'Doberman']
# Filename n02087394_Rhodesian_ridgeback.JPEG: predictions ['Rhodesian ridgeback', 'boxer', 'American Staffordshire terrier']
# Filename n02088238_basset.JPEG: predictions ['basset', 'beagle', 'bloodhound']
# Filename n02088364_beagle.JPEG: predictions ['bluetick', 'beagle', 'Walker hound']
# Filename n02088466_bloodhound.JPEG: predictions ['bloodhound', 'maillot tank suit', 'bikini']
# Filename n02089078_black-and-tan_coonhound.JPEG: predictions ['black-and-tan coonhound', 'Gordon setter', 'bloodhound']
# Filename n02089867_Walker_hound.JPEG: predictions ['Walker hound', 'English foxhound', 'beagle']
# Filename n02089973_English_foxhound.JPEG: predictions ['English foxhound', 'Walker hound', 'beagle']
# Filename n02090622_borzoi.JPEG: predictions ['borzoi', 'kuvasz', 'English setter']
# Filename n02090721_Irish_wolfhound.JPEG: predictions ['Irish wolfhound', 'Scottish deerhound', 'Irish terrier']
# Filename n02091032_Italian_greyhound.JPEG: predictions ['Italian greyhound', 'feather boa', 'Weimaraner']
# Filename n02091244_Ibizan_hound.JPEG: predictions ['Ibizan hound', 'whippet', 'Great Dane']
# Filename n02091467_Norwegian_elkhound.JPEG: predictions ['Norwegian elkhound', 'Eskimo dog', 'German shepherd']
# Filename n02091635_otterhound.JPEG: predictions ['Irish terrier', 'otterhound', 'Tibetan terrier']
# Filename n02092002_Scottish_deerhound.JPEG: predictions ['Scottish deerhound', 'Irish wolfhound', 'Tibetan terrier']
# Filename n02092339_Weimaraner.JPEG: predictions ['Weimaraner', 'cowboy hat', 'barrow']
# Filename n02093256_Staffordshire_bullterrier.JPEG: predictions ['Staffordshire bullterrier', 'American Staffordshire terrier', 'bull mastiff']
# Filename n02093647_Bedlington_terrier.JPEG: predictions ['Bedlington terrier', 'Dandie Dinmont', 'Sealyham terrier']
# Filename n02093754_Border_terrier.JPEG: predictions ['Border terrier', 'Norfolk terrier', 'water tower']
# Filename n02093859_Kerry_blue_terrier.JPEG: predictions ['Kerry blue terrier', 'Irish terrier', 'Lakeland terrier']
# Filename n02094114_Norfolk_terrier.JPEG: predictions ['Norfolk terrier', 'Norwich terrier', 'Irish terrier']
# Filename n02094258_Norwich_terrier.JPEG: predictions ['Norwich terrier', 'Norfolk terrier', 'Australian terrier']
# Filename n02094433_Yorkshire_terrier.JPEG: predictions ['Yorkshire terrier', 'silky terrier', 'Australian terrier']
# Filename n02095570_Lakeland_terrier.JPEG: predictions ['Lakeland terrier', 'wire-haired fox terrier', 'Kerry blue terrier']
# Filename n02095889_Sealyham_terrier.JPEG: predictions ['Sealyham terrier', 'Dandie Dinmont', 'wire-haired fox terrier']
# Filename n02096294_Australian_terrier.JPEG: predictions ['Australian terrier', 'Yorkshire terrier', 'silky terrier']
# Filename n02096437_Dandie_Dinmont.JPEG: predictions ['Dandie Dinmont', 'soft-coated wheaten terrier', 'oil filter']
# Filename n02096585_Boston_bull.JPEG: predictions ['Boston bull', 'toy terrier', 'Chihuahua']
# Filename n02097130_giant_schnauzer.JPEG: predictions ['giant schnauzer', 'standard schnauzer', 'miniature schnauzer']
# Filename n02097209_standard_schnauzer.JPEG: predictions ['standard schnauzer', 'miniature schnauzer', 'giant schnauzer']
# Filename n02097298_Scotch_terrier.JPEG: predictions ['Scotch terrier', 'Mexican hairless', 'plunger']
# Filename n02097658_silky_terrier.JPEG: predictions ['silky terrier', 'Australian terrier', 'paper towel']
# Filename n02098105_soft-coated_wheaten_terrier.JPEG: predictions ['soft-coated wheaten terrier', 'Irish wolfhound', 'Lakeland terrier']
# Filename n02098286_West_Highland_white_terrier.JPEG: predictions ['West Highland white terrier', 'cairn', 'Maltese dog']
# Filename n02099267_flat-coated_retriever.JPEG: predictions ['flat-coated retriever', 'Newfoundland', 'Labrador retriever']
# Filename n02099429_curly-coated_retriever.JPEG: predictions ['curly-coated retriever', 'Irish water spaniel', 'Kerry blue terrier']
# Filename n02099601_golden_retriever.JPEG: predictions ['golden retriever', 'Labrador retriever', 'clumber']
# Filename n02099849_Chesapeake_Bay_retriever.JPEG: predictions ['Chesapeake Bay retriever', 'Labrador retriever', 'curly-coated retriever']
# Filename n02100236_German_short-haired_pointer.JPEG: predictions ['German short-haired pointer', 'Weimaraner', 'English springer']
# Filename n02100583_vizsla.JPEG: predictions ['vizsla', 'plastic bag', 'Rhodesian ridgeback']
# Filename n02100877_Irish_setter.JPEG: predictions ['Irish setter', 'Gordon setter', 'English setter']
# Filename n02101006_Gordon_setter.JPEG: predictions ['Gordon setter', 'flat-coated retriever', 'Japanese spaniel']
# Filename n02101388_Brittany_spaniel.JPEG: predictions ['Welsh springer spaniel', 'Brittany spaniel', 'Irish setter']
# Filename n02102040_English_springer.JPEG: predictions ['English springer', 'EntleBucher', 'Brittany spaniel']
# Filename n02102177_Welsh_springer_spaniel.JPEG: predictions ['Welsh springer spaniel', 'Brittany spaniel', 'English springer']
# Filename n02102318_cocker_spaniel.JPEG: predictions ['cocker spaniel', 'clumber', 'Sussex spaniel']
# Filename n02102973_Irish_water_spaniel.JPEG: predictions ['Irish water spaniel', 'Sussex spaniel', 'curly-coated retriever']
# Filename n02104029_kuvasz.JPEG: predictions ['kuvasz', 'Great Pyrenees', 'golden retriever']
# Filename n02104365_schipperke.JPEG: predictions ['schipperke', 'bath towel', 'groenendael']
# Filename n02105162_malinois.JPEG: predictions ['malinois', 'German shepherd', 'Norwegian elkhound']
# Filename n02105251_briard.JPEG: predictions ['briard', 'Bouvier des Flandres', 'Tibetan terrier']
# Filename n02105412_kelpie.JPEG: predictions ['Chihuahua', 'kelpie', 'Pembroke']
# Filename n02105641_Old_English_sheepdog.JPEG: predictions ['Old English sheepdog', 'komondor', 'miniskirt']
# Filename n02105855_Shetland_sheepdog.JPEG: predictions ['Shetland sheepdog', 'toy poodle', 'collie']
# Filename n02106030_collie.JPEG: predictions ['Shetland sheepdog', 'chow', 'collie']
# Filename n02106382_Bouvier_des_Flandres.JPEG: predictions ['Bouvier des Flandres', 'briard', 'giant schnauzer']
# Filename n02106550_Rottweiler.JPEG: predictions ['Rottweiler', 'Doberman', 'Airedale']
# Filename n02106662_German_shepherd.JPEG: predictions ['German shepherd', 'Gordon setter', 'Rottweiler']
# Filename n02107312_miniature_pinscher.JPEG: predictions ['miniature pinscher', 'Chihuahua', 'toy terrier']
# Filename n02107574_Greater_Swiss_Mountain_dog.JPEG: predictions ['Greater Swiss Mountain dog', 'EntleBucher', 'Appenzeller']
# Filename n02107683_Bernese_mountain_dog.JPEG: predictions ['Bernese mountain dog', 'Appenzeller', 'Greater Swiss Mountain dog']
# Filename n02108000_EntleBucher.JPEG: predictions ['EntleBucher', 'Greater Swiss Mountain dog', 'Appenzeller']
# Filename n02108089_boxer.JPEG: predictions ['boxer', 'bull mastiff', 'French bulldog']
# Filename n02108422_bull_mastiff.JPEG: predictions ['bull mastiff', 'pug', 'Great Dane']
# Filename n02108915_French_bulldog.JPEG: predictions ['French bulldog', 'pug', 'American Staffordshire terrier']
# Filename n02109047_Great_Dane.JPEG: predictions ['Great Dane', 'American Staffordshire terrier', 'Doberman']
# Filename n02109525_Saint_Bernard.JPEG: predictions ['Saint Bernard', 'Tibetan mastiff', 'Leonberg']
# Filename n02110063_malamute.JPEG: predictions ['malamute', 'Eskimo dog', 'Norwegian elkhound']
# Filename n02110185_Siberian_husky.JPEG: predictions ['keeshond', 'Newfoundland', 'Great Pyrenees']
# Filename n02110341_dalmatian.JPEG: predictions ['dalmatian', 'wooden spoon', 'Bernese mountain dog']
# Filename n02110806_basenji.JPEG: predictions ['basenji', 'doormat', 'toy terrier']
# Filename n02110958_pug.JPEG: predictions ['pug', 'wig', 'bull mastiff']
# Filename n02111129_Leonberg.JPEG: predictions ['Leonberg', 'Gordon setter', 'Afghan hound']
# Filename n02111500_Great_Pyrenees.JPEG: predictions ['Great Pyrenees', 'kuvasz', 'Samoyed']
# Filename n02111889_Samoyed.JPEG: predictions ['Samoyed', 'Arctic fox', 'Great Pyrenees']
# Filename n02112018_Pomeranian.JPEG: predictions ['Pomeranian', 'chow', 'Pekinese']
# Filename n02112350_keeshond.JPEG: predictions ['keeshond', 'Pomeranian', 'stethoscope']
# Filename n02112706_Brabancon_griffon.JPEG: predictions ['Brabancon griffon', 'Yorkshire terrier', 'Border terrier']
# Filename n02113023_Pembroke.JPEG: predictions ['Pembroke', 'Cardigan', 'nipple']
# Filename n02113624_toy_poodle.JPEG: predictions ['miniature poodle', 'toy poodle', 'seat belt']
# Filename n02113712_miniature_poodle.JPEG: predictions ['miniature poodle', 'toy poodle', 'Irish water spaniel']
# Filename n02113799_standard_poodle.JPEG: predictions ['standard poodle', 'toy poodle', 'miniature poodle']
# Filename n02114367_timber_wolf.JPEG: predictions ['timber wolf', 'red wolf', 'dingo']
# Filename n02114548_white_wolf.JPEG: predictions ['white wolf', 'timber wolf', 'Arctic fox']
# Filename n02114712_red_wolf.JPEG: predictions ['red wolf', 'monarch', 'coyote']
# Filename n02115641_dingo.JPEG: predictions ['dingo', 'gazelle', 'dhole']
# Filename n02115913_dhole.JPEG: predictions ['dhole', 'red wolf', 'red fox']
# Filename n02116738_African_hunting_dog.JPEG: predictions ['African hunting dog', 'hyena', 'dhole']
# Filename n02119022_red_fox.JPEG: predictions ['red fox', 'grey fox', 'kit fox']
# Filename n02119789_kit_fox.JPEG: predictions ['kit fox', 'grey fox', 'red fox']
# Filename n02120079_Arctic_fox.JPEG: predictions ['Arctic fox', 'kit fox', 'white wolf']
# Filename n02123045_tabby.JPEG: predictions ['Egyptian cat', 'tiger cat', 'tabby']
# Filename n02123159_tiger_cat.JPEG: predictions ['tabby', 'tiger cat', 'Egyptian cat']
# Filename n02123394_Persian_cat.JPEG: predictions ['Persian cat', 'lynx', 'tiger cat']
# Filename n02124075_Egyptian_cat.JPEG: predictions ['Egyptian cat', 'tabby', 'lynx']
# Filename n02125311_cougar.JPEG: predictions ['cougar', 'lynx', 'lion']
# Filename n02127052_lynx.JPEG: predictions ['lynx', 'ruffed grouse', 'pickup']
# Filename n02128757_snow_leopard.JPEG: predictions ['snow leopard', 'leopard', 'jaguar']
# Filename n02128925_jaguar.JPEG: predictions ['cougar', 'dingo', 'lion']
# Filename n02129165_lion.JPEG: predictions ['lion', 'Arabian camel', 'baboon']
# Filename n02130308_cheetah.JPEG: predictions ['cheetah', 'jaguar', 'leopard']
# Filename n02132136_brown_bear.JPEG: predictions ['brown bear', 'sloth bear', 'American black bear']
# Filename n02133161_American_black_bear.JPEG: predictions ['American black bear', 'sloth bear', 'brown bear']
# Filename n02134418_sloth_bear.JPEG: predictions ['sloth bear', 'window shade', 'electric locomotive']
# Filename n02137549_mongoose.JPEG: predictions ['mongoose', 'meerkat', 'weasel']
# Filename n02138441_meerkat.JPEG: predictions ['meerkat', 'mongoose', 'marmot']
# Filename n02165456_ladybug.JPEG: predictions ['ladybug', 'leaf beetle', 'weevil']
# Filename n02167151_ground_beetle.JPEG: predictions ['ground beetle', 'tiger beetle', 'leaf beetle']
# Filename n02168699_long-horned_beetle.JPEG: predictions ['long-horned beetle', 'tiger beetle', 'ground beetle']
# Filename n02172182_dung_beetle.JPEG: predictions ['dung beetle', 'rhinoceros beetle', 'ground beetle']
# Filename n02174001_rhinoceros_beetle.JPEG: predictions ['rhinoceros beetle', 'ground beetle', 'dung beetle']
# Filename n02177972_weevil.JPEG: predictions ['weevil', 'leaf beetle', 'leafhopper']
# Filename n02206856_bee.JPEG: predictions ['bee', 'fly', 'apiary']
# Filename n02219486_ant.JPEG: predictions ['ant', 'basketball', 'cricket']
# Filename n02226429_grasshopper.JPEG: predictions ['cricket', 'grasshopper', 'cockroach']
# Filename n02231487_walking_stick.JPEG: predictions ['walking stick', 'fire screen', 'window screen']
# Filename n02233338_cockroach.JPEG: predictions ['cockroach', 'tray', 'bolo tie']
# Filename n02236044_mantis.JPEG: predictions ['mantis', 'walking stick', 'grasshopper']
# Filename n02259212_leafhopper.JPEG: predictions ['leafhopper', 'fly', 'cicada']
# Filename n02264363_lacewing.JPEG: predictions ['lacewing', 'cricket', 'cockroach']
# Filename n02268443_dragonfly.JPEG: predictions ['dragonfly', 'damselfly', 'lacewing']
# Filename n02276258_admiral.JPEG: predictions ['admiral', 'rapeseed', 'kimono']
# Filename n02277742_ringlet.JPEG: predictions ['ringlet', 'monarch', 'sulphur butterfly']
# Filename n02279972_monarch.JPEG: predictions ['monarch', 'lycaenid', 'ringlet']
# Filename n02281406_sulphur_butterfly.JPEG: predictions ['sulphur butterfly', 'cabbage butterfly', 'ringlet']
# Filename n02281787_lycaenid.JPEG: predictions ['lycaenid', 'ringlet', 'cabbage butterfly']
# Filename n02317335_starfish.JPEG: predictions ['starfish', 'leatherback turtle', 'sea urchin']
# Filename n02321529_sea_cucumber.JPEG: predictions ['sea cucumber', 'guinea pig', 'hog']
# Filename n02325366_wood_rabbit.JPEG: predictions ['wood rabbit', 'hare', 'Angora']
# Filename n02326432_hare.JPEG: predictions ['hare', 'magpie', 'jay']
# Filename n02342885_hamster.JPEG: predictions ['hamster', 'broccoli', 'ladybug']
# Filename n02346627_porcupine.JPEG: predictions ['porcupine', 'wombat', 'Angora']
# Filename n02356798_fox_squirrel.JPEG: predictions ['fox squirrel', 'grey fox', 'three-toed sloth']
# Filename n02363005_beaver.JPEG: predictions ['beaver', 'porcupine', 'guinea pig']
# Filename n02364673_guinea_pig.JPEG: predictions ['guinea pig', 'hamster', 'basenji']
# Filename n02389026_sorrel.JPEG: predictions ['sorrel', 'ox', 'bison']
# Filename n02395406_hog.JPEG: predictions ['hog', 'Egyptian cat', 'butcher shop']
# Filename n02396427_wild_boar.JPEG: predictions ['wild boar', 'hog', 'bison']
# Filename n02397096_warthog.JPEG: predictions ['warthog', 'wild boar', 'tusker']
# Filename n02403003_ox.JPEG: predictions ['ox', 'ram', 'bison']
# Filename n02408429_water_buffalo.JPEG: predictions ['water buffalo', 'ox', 'wild boar']
# Filename n02410509_bison.JPEG: predictions ['bison', 'water buffalo', 'wild boar']
# Filename n02415577_bighorn.JPEG: predictions ['bighorn', 'ram', 'ibex']
# Filename n02417914_ibex.JPEG: predictions ['ibex', 'breakwater', 'rock crab']
# Filename n02422106_hartebeest.JPEG: predictions ['hartebeest', 'impala', 'gazelle']
# Filename n02423022_gazelle.JPEG: predictions ['gazelle', 'impala', 'weasel']
# Filename n02437312_Arabian_camel.JPEG: predictions ['Arabian camel', 'horse cart', 'hartebeest']
# Filename n02437616_llama.JPEG: predictions ['llama', 'wallaby', 'hyena']
# Filename n02442845_mink.JPEG: predictions ['mink', 'weasel', 'polecat']
# Filename n02443114_polecat.JPEG: predictions ['weasel', 'polecat', 'mink']
# Filename n02443484_black-footed_ferret.JPEG: predictions ['black-footed ferret', 'weasel', 'polecat']
# Filename n02445715_skunk.JPEG: predictions ['skunk', 'porcupine', 'polecat']
# Filename n02447366_badger.JPEG: predictions ['badger', 'weasel', 'night snake']
# Filename n02454379_armadillo.JPEG: predictions ['armadillo', 'spider web', 'grey fox']
# Filename n02480495_orangutan.JPEG: predictions ['orangutan', 'siamang', 'howler monkey']
# Filename n02480855_gorilla.JPEG: predictions ['gorilla', 'chimpanzee', 'macaque']
# Filename n02481823_chimpanzee.JPEG: predictions ['chimpanzee', 'gorilla', 'siamang']
# Filename n02483708_siamang.JPEG: predictions ['siamang', 'gibbon', 'spider monkey']
# Filename n02484975_guenon.JPEG: predictions ['guenon', 'patas', 'titi']
# Filename n02486261_patas.JPEG: predictions ['patas', 'guenon', 'titi']
# Filename n02487347_macaque.JPEG: predictions ['macaque', 'patas', 'titi']
# Filename n02488291_langur.JPEG: predictions ['langur', 'baboon', 'patas']
# Filename n02488702_colobus.JPEG: predictions ['colobus', 'langur', 'guenon']
# Filename n02490219_marmoset.JPEG: predictions ['marmoset', 'titi', 'guenon']
# Filename n02492035_capuchin.JPEG: predictions ['capuchin', 'titi', 'guenon']
# Filename n02492660_howler_monkey.JPEG: predictions ['howler monkey', 'spider monkey', 'colobus']
# Filename n02493793_spider_monkey.JPEG: predictions ['spider monkey', 'patas', 'howler monkey']
# Filename n02494079_squirrel_monkey.JPEG: predictions ['squirrel monkey', 'spider monkey', 'titi']
# Filename n02497673_Madagascar_cat.JPEG: predictions ['Madagascar cat', 'badger', 'indri']
# Filename n02504013_Indian_elephant.JPEG: predictions ['Indian elephant', 'tusker', 'African elephant']
# Filename n02504458_African_elephant.JPEG: predictions ['African elephant', 'tusker', 'Indian elephant']
# Filename n02509815_lesser_panda.JPEG: predictions ['lesser panda', 'polecat', 'giant panda']
# Filename n02514041_barracouta.JPEG: predictions ['barracouta', 'tench', 'gar']
# Filename n02526121_eel.JPEG: predictions ['eel', 'slug', 'gar']
# Filename n02536864_coho.JPEG: predictions ['coho', 'sturgeon', 'barracouta']
# Filename n02607072_anemone_fish.JPEG: predictions ['anemone fish', 'sea anemone', 'coral reef']
# Filename n02640242_sturgeon.JPEG: predictions ['sturgeon', 'lakeside', 'grey whale']
# Filename n02641379_gar.JPEG: predictions ['gar', 'reel', 'sturgeon']
# Filename n02655020_puffer.JPEG: predictions ['puffer', 'eel', 'electric ray']
# Filename n02666196_abacus.JPEG: predictions ['abacus', 'screwdriver', 'syringe']
# Filename n02667093_abaya.JPEG: predictions ['abaya', 'sunglasses', 'miniskirt']
# Filename n02672831_accordion.JPEG: predictions ['accordion', 'perfume', 'toaster']
# Filename n02687172_aircraft_carrier.JPEG: predictions ['aircraft carrier', 'warplane', 'dock']
# Filename n02699494_altar.JPEG: predictions ['altar', 'organ', 'vault']
# Filename n02701002_ambulance.JPEG: predictions ['ambulance', 'police van', 'stretcher']
# Filename n02708093_analog_clock.JPEG: predictions ['analog clock', 'wall clock', 'odometer']
# Filename n02727426_apiary.JPEG: predictions ['apiary', 'solar dish', 'ashcan']
# Filename n02730930_apron.JPEG: predictions ['apron', 'desk', 'scale']
# Filename n02769748_backpack.JPEG: predictions ['backpack', 'mailbag', 'seat belt']
# Filename n02776631_bakery.JPEG: predictions ['bakery', 'medicine chest', 'china cabinet']
# Filename n02782093_balloon.JPEG: predictions ['balloon', 'water tower', 'airship']
# Filename n02783161_ballpoint.JPEG: predictions ['ballpoint', 'fountain pen', 'drumstick']
# Filename n02786058_Band_Aid.JPEG: predictions ['Band Aid', 'packet', 'teddy']
# Filename n02788148_bannister.JPEG: predictions ['bannister', 'coil', 'typewriter keyboard']
# Filename n02790996_barbell.JPEG: predictions ['barbell', 'horizontal bar', 'Dutch oven']
# Filename n02791124_barber_chair.JPEG: predictions ['barber chair', 'barbershop', 'throne']
# Filename n02793495_barn.JPEG: predictions ['barn', 'church', 'boathouse']
# Filename n02794156_barometer.JPEG: predictions ['barometer', 'wall clock', 'lampshade']
# Filename n02795169_barrel.JPEG: predictions ['rain barrel', 'barrel', 'milk can']
# Filename n02799071_baseball.JPEG: predictions ['baseball', 'rugby ball', 'drum']
# Filename n02802426_basketball.JPEG: predictions ['basketball', 'knee pad', 'volleyball']
# Filename n02804414_bassinet.JPEG: predictions ['bassinet', 'cradle', 'crib']
# Filename n02807133_bathing_cap.JPEG: predictions ['bathing cap', 'stingray', 'maillot tank suit']
# Filename n02808304_bath_towel.JPEG: predictions ['bath towel', 'teddy', 'window shade']
# Filename n02808440_bathtub.JPEG: predictions ['bathtub', 'tub', 'washbasin']
# Filename n02814860_beacon.JPEG: predictions ['beacon', 'picket fence', 'pedestal']
# Filename n02817516_bearskin.JPEG: predictions ['bearskin', 'jellyfish', 'pickelhaube']
# Filename n02825657_bell_cote.JPEG: predictions ['bell cote', 'church', 'stone wall']
# Filename n02834397_bib.JPEG: predictions ['bib', 'shield', 'barbershop']
# Filename n02837789_bikini.JPEG: predictions ['bikini', 'brassiere', 'maillot']
# Filename n02840245_binder.JPEG: predictions ['typewriter keyboard', 'toilet tissue', 'space bar']
# Filename n02841315_binoculars.JPEG: predictions ['binoculars', 'joystick', 'switch']
# Filename n02859443_boathouse.JPEG: predictions ['boathouse', 'lumbermill', 'lakeside']
# Filename n02860847_bobsled.JPEG: predictions ['bobsled', 'beacon', 'sliding door']
# Filename n02865351_bolo_tie.JPEG: predictions ['bolo tie', 'buckle', 'ladle']
# Filename n02870880_bookcase.JPEG: predictions ['bookcase', 'library', 'tobacco shop']
# Filename n02871525_bookshop.JPEG: predictions ['bookshop', 'tobacco shop', 'bakery']
# Filename n02877765_bottlecap.JPEG: predictions ['bottlecap', 'thimble', 'beer bottle']
# Filename n02883205_bow_tie.JPEG: predictions ['bow tie', 'suit', 'radiator']
# Filename n02892201_brass.JPEG: predictions ['manhole cover', 'brass', 'sundial']
# Filename n02892767_brassiere.JPEG: predictions ['brassiere', 'miniskirt', 'dumbbell']
# Filename n02895154_breastplate.JPEG: predictions ['breastplate', 'cuirass', 'throne']
# Filename n02906734_broom.JPEG: predictions ['broom', 'shovel', 'swab']
# Filename n02909870_bucket.JPEG: predictions ['bucket', 'shovel', 'pill bottle']
# Filename n02916936_bulletproof_vest.JPEG: predictions ['bulletproof vest', 'military uniform', 'holster']
# Filename n02917067_bullet_train.JPEG: predictions ['bullet train', 'electric locomotive', 'trilobite']
# Filename n02927161_butcher_shop.JPEG: predictions ['butcher shop', 'cleaver', 'Dungeness crab']
# Filename n02939185_caldron.JPEG: predictions ['caldron', 'barrel', 'vase']
# Filename n02948072_candle.JPEG: predictions ['candle', 'lighter', 'torch']
# Filename n02950826_cannon.JPEG: predictions ['cannon', 'mortar', 'tank']
# Filename n02951585_can_opener.JPEG: predictions ['can opener', 'spatula', 'letter opener']
# Filename n02963159_cardigan.JPEG: predictions ['cardigan', 'teddy', 'wool']
# Filename n02965783_car_mirror.JPEG: predictions ['car mirror', 'television', 'iron']
# Filename n02966687_carpenter's_kit.JPEG: predictions ["carpenter's kit", 'screwdriver', 'power drill']
# Filename n02971356_carton.JPEG: predictions ['carton', 'modem', 'projector']
# Filename n02974003_car_wheel.JPEG: predictions ['car wheel', 'disk brake', 'racer']
# Filename n02978881_cassette.JPEG: predictions ['cassette', 'tape player', 'cassette player']
# Filename n02979186_cassette_player.JPEG: predictions ['cassette player', 'tape player', 'hard disc']
# Filename n02980441_castle.JPEG: predictions ['castle', 'church', 'water tower']
# Filename n02988304_CD_player.JPEG: predictions ['CD player', 'tape player', 'cassette player']
# Filename n02992211_cello.JPEG: predictions ['cello', 'violin', 'banjo']
# Filename n02992529_cellular_telephone.JPEG: predictions ['cellular telephone', 'hand-held computer', 'screen']
# Filename n03000134_chainlink_fence.JPEG: predictions ['chainlink fence', 'combination lock', 'prison']
# Filename n03000247_chain_mail.JPEG: predictions ['chain mail', 'cuirass', 'guinea pig']
# Filename n03000684_chain_saw.JPEG: predictions ['chain saw', 'lumbermill', 'stinkhorn']
# Filename n03016953_chiffonier.JPEG: predictions ['chiffonier', 'china cabinet', 'four-poster']
# Filename n03017168_chime.JPEG: predictions ['chime', 'bell cote', 'loudspeaker']
# Filename n03018349_china_cabinet.JPEG: predictions ['china cabinet', 'bookcase', 'groom']
# Filename n03028079_church.JPEG: predictions ['church', 'ashcan', 'barn']
# Filename n03032252_cinema.JPEG: predictions ['cinema', 'barbershop', 'restaurant']
# Filename n03041632_cleaver.JPEG: predictions ['butcher shop', 'cleaver', 'scale']
# Filename n03045698_cloak.JPEG: predictions ['gown', 'overskirt', 'kimono']
# Filename n03047690_clog.JPEG: predictions ['clog', 'Loafer', 'sock']
# Filename n03062245_cocktail_shaker.JPEG: predictions ['cocktail shaker', 'pop bottle', 'eggnog']
# Filename n03063689_coffeepot.JPEG: predictions ['coffeepot', 'coffee mug', 'teapot']
# Filename n03065424_coil.JPEG: predictions ['coil', 'hen-of-the-woods', 'maze']
# Filename n03075370_combination_lock.JPEG: predictions ['combination lock', 'safe', 'padlock']
# Filename n03089624_confectionery.JPEG: predictions ['groom', 'wine bottle', 'grocery store']
# Filename n03095699_container_ship.JPEG: predictions ['container ship', 'liner', 'dock']
# Filename n03100240_convertible.JPEG: predictions ['convertible', 'sports car', 'car wheel']
# Filename n03110669_cornet.JPEG: predictions ['cornet', 'French horn', 'sax']
# Filename n03124043_cowboy_boot.JPEG: predictions ['cowboy boot', 'cowboy hat', 'buckle']
# Filename n03124170_cowboy_hat.JPEG: predictions ['cowboy hat', 'sombrero', 'cowboy boot']
# Filename n03126707_crane.JPEG: predictions ['crane', 'boathouse', 'pier']
# Filename n03127747_crash_helmet.JPEG: predictions ['crash helmet', 'backpack', 'disk brake']
# Filename n03127925_crate.JPEG: predictions ['crate', 'carton', 'ashcan']
# Filename n03133878_Crock_Pot.JPEG: predictions ['Crock Pot', 'teapot', 'coffeepot']
# Filename n03134739_croquet_ball.JPEG: predictions ['croquet ball', 'golf ball', 'tiger cat']
# Filename n03141823_crutch.JPEG: predictions ['crutch', 'tripod', 'accordion']
# Filename n03160309_dam.JPEG: predictions ['dam', 'plate', 'cowboy hat']
# Filename n03179701_desk.JPEG: predictions ['desk', 'laptop', 'notebook']
# Filename n03180011_desktop_computer.JPEG: predictions ['desktop computer', 'monitor', 'desk']
# Filename n03188531_diaper.JPEG: predictions ['diaper', 'bib', 'apron']
# Filename n03196217_digital_clock.JPEG: predictions ['digital clock', 'digital watch', 'microwave']
# Filename n03197337_digital_watch.JPEG: predictions ['digital watch', 'cassette player', 'cassette']
# Filename n03207743_dishrag.JPEG: predictions ['dishrag', 'wool', 'cardigan']
# Filename n03207941_dishwasher.JPEG: predictions ['dishwasher', 'shopping cart', 'shopping basket']
# Filename n03208938_disk_brake.JPEG: predictions ['disk brake', 'oil filter', 'black widow']
# Filename n03218198_dogsled.JPEG: predictions ['dogsled', 'Eskimo dog', 'EntleBucher']
# Filename n03220513_dome.JPEG: predictions ['dome', 'mosque', 'planetarium']
# Filename n03223299_doormat.JPEG: predictions ['doormat', 'hamper', 'wool']
# Filename n03249569_drum.JPEG: predictions ['drum', 'drumstick', 'banjo']
# Filename n03250847_drumstick.JPEG: predictions ['drumstick', 'drum', 'hammer']
# Filename n03255030_dumbbell.JPEG: predictions ['dumbbell', 'barbell', 'punching bag']
# Filename n03271574_electric_fan.JPEG: predictions ['electric fan', 'microwave', 'loudspeaker']
# Filename n03272010_electric_guitar.JPEG: predictions ['electric guitar', 'acoustic guitar', 'pick']
# Filename n03272562_electric_locomotive.JPEG: predictions ['electric locomotive', 'passenger car', 'sloth bear']
# Filename n03291819_envelope.JPEG: predictions ['envelope', 'wallet', 'purse']
# Filename n03297495_espresso_maker.JPEG: predictions ['espresso maker', 'espresso', 'coffeepot']
# Filename n03314780_face_powder.JPEG: predictions ['face powder', 'paintbrush', 'lipstick']
# Filename n03337140_file.JPEG: predictions ['file', 'hamper', 'chiffonier']
# Filename n03344393_fireboat.JPEG: predictions ['fireboat', 'liner', 'amphibian']
# Filename n03345487_fire_engine.JPEG: predictions ['fire engine', 'pickup', 'Model T']
# Filename n03355925_flagpole.JPEG: predictions ['flagpole', 'pole', 'planetarium']
# Filename n03372029_flute.JPEG: predictions ['flute', 'whistle', 'lipstick']
# Filename n03376595_folding_chair.JPEG: predictions ['folding chair', 'dining table', 'volleyball']
# Filename n03384352_forklift.JPEG: predictions ['forklift', 'plunger', 'tricycle']
# Filename n03388183_fountain_pen.JPEG: predictions ['fountain pen', 'scabbard', 'hook']
# Filename n03393912_freight_car.JPEG: predictions ['freight car', 'sliding door', 'odometer']
# Filename n03394916_French_horn.JPEG: predictions ['French horn', 'bassoon', 'oboe']
# Filename n03400231_frying_pan.JPEG: predictions ['frying pan', 'Dutch oven', 'wok']
# Filename n03424325_gasmask.JPEG: predictions ['gasmask', 'syringe', 'bib']
# Filename n03425413_gas_pump.JPEG: predictions ['gas pump', 'Polaroid camera', 'pay-phone']
# Filename n03444034_go-kart.JPEG: predictions ['go-kart', 'crash helmet', 'lawn mower']
# Filename n03445777_golf_ball.JPEG: predictions ['golf ball', 'thimble', 'ping-pong ball']
# Filename n03445924_golfcart.JPEG: predictions ['golfcart', 'parallel bars', 'jeep']
# Filename n03447721_gong.JPEG: predictions ['gong', 'chime', 'shield']
# Filename n03450230_gown.JPEG: predictions ['gown', 'groom', 'feather boa']
# Filename n03452741_grand_piano.JPEG: predictions ['grand piano', 'upright', 'pool table']
# Filename n03459775_grille.JPEG: predictions ['grille', 'beach wagon', 'limousine']
# Filename n03461385_grocery_store.JPEG: predictions ['grocery store', 'custard apple', 'cucumber']
# Filename n03467068_guillotine.JPEG: predictions ['guillotine', 'prison', 'thatch']
# Filename n03476991_hair_spray.JPEG: predictions ['hair spray', 'bathtub', 'hand blower']
# Filename n03478589_half_track.JPEG: predictions ['half track', 'cannon', 'tank']
# Filename n03481172_hammer.JPEG: predictions ['hammer', 'hatchet', 'flute']
# Filename n03483316_hand_blower.JPEG: predictions ['hand blower', 'microphone', 'lipstick']
# Filename n03485407_hand-held_computer.JPEG: predictions ['hand-held computer', 'space bar', 'radio']
# Filename n03485794_handkerchief.JPEG: predictions ['handkerchief', 'packet', 'apron']
# Filename n03494278_harmonica.JPEG: predictions ['harmonica', 'street sign', 'oystercatcher']
# Filename n03495258_harp.JPEG: predictions ['harp', 'oboe', 'grocery store']
# Filename n03496892_harvester.JPEG: predictions ['harvester', 'thresher', 'crane']
# Filename n03527444_holster.JPEG: predictions ['holster', 'revolver', 'scabbard']
# Filename n03529860_home_theater.JPEG: predictions ['home theater', 'entertainment center', 'television']
# Filename n03530642_honeycomb.JPEG: predictions ['honeycomb', 'apiary', 'chiton']
# Filename n03534580_hoopskirt.JPEG: predictions ['hoopskirt', 'overskirt', 'gown']
# Filename n03535780_horizontal_bar.JPEG: predictions ['horizontal bar', 'parallel bars', 'swing']
# Filename n03538406_horse_cart.JPEG: predictions ['horse cart', 'plow', 'oxcart']
# Filename n03584254_iPod.JPEG: predictions ['iPod', 'robin', 'hard disc']
# Filename n03584829_iron.JPEG: predictions ['iron', 'can opener', 'cassette player']
# Filename n03590841_jack-o'-lantern.JPEG: predictions ["jack-o'-lantern", 'power drill', 'head cabbage']
# Filename n03594945_jeep.JPEG: predictions ['jeep', 'police van', 'pickup']
# Filename n03595614_jersey.JPEG: predictions ['jersey', 'sweatshirt', 'maillot']
# Filename n03598930_jigsaw_puzzle.JPEG: predictions ['jigsaw puzzle', 'window screen', 'tray']
# Filename n03602883_joystick.JPEG: predictions ['joystick', 'microphone', 'holster']
# Filename n03617480_kimono.JPEG: predictions ['kimono', 'trench coat', 'mortarboard']
# Filename n03623198_knee_pad.JPEG: predictions ['knee pad', 'crash helmet', 'rugby ball']
# Filename n03630383_lab_coat.JPEG: predictions ['lab coat', 'water jug', 'bakery']
# Filename n03633091_ladle.JPEG: predictions ['ladle', 'soup bowl', 'strainer']
# Filename n03637318_lampshade.JPEG: predictions ['table lamp', 'lampshade', 'hook']
# Filename n03649909_lawn_mower.JPEG: predictions ['tractor', 'lawn mower', 'harvester']
# Filename n03657121_lens_cap.JPEG: predictions ['lens cap', 'stopwatch', 'cellular telephone']
# Filename n03658185_letter_opener.JPEG: predictions ['letter opener', 'spatula', 'wooden spoon']
# Filename n03662601_lifeboat.JPEG: predictions ['lifeboat', 'pole', 'flagpole']
# Filename n03666591_lighter.JPEG: predictions ['lighter', 'rubber eraser', 'matchstick']
# Filename n03670208_limousine.JPEG: predictions ['limousine', 'snowplow', 'giant panda']
# Filename n03676483_lipstick.JPEG: predictions ['lipstick', 'web site', 'red wine']
# Filename n03680355_Loafer.JPEG: predictions ['Loafer', 'sandal', 'buckle']
# Filename n03690938_lotion.JPEG: predictions ['lotion', 'face powder', 'sunscreen']
# Filename n03706229_magnetic_compass.JPEG: predictions ['magnetic compass', 'stopwatch', 'stethoscope']
# Filename n03710193_mailbox.JPEG: predictions ['mailbox', 'safe', 'padlock']
# Filename n03710637_maillot.JPEG: predictions ['maillot', 'maillot tank suit', 'brassiere']
# Filename n03710721_maillot.JPEG: predictions ['maillot tank suit', 'maillot', 'sarong']
# Filename n03720891_maraca.JPEG: predictions ['pinwheel', 'ice lolly', 'maraca']
# Filename n03721384_marimba.JPEG: predictions ['marimba', 'sandbar', 'sarong']
# Filename n03724870_mask.JPEG: predictions ['mask', 'vestment', 'feather boa']
# Filename n03733131_maypole.JPEG: predictions ['maypole', 'sunglasses', 'sunglass']
# Filename n03733281_maze.JPEG: predictions ['tray', 'car mirror', 'vault']
# Filename n03733805_measuring_cup.JPEG: predictions ['measuring cup', 'water jug', 'vase']
# Filename n03743016_megalith.JPEG: predictions ['megalith', 'brass', 'patas']
# Filename n03759954_microphone.JPEG: predictions ['microphone', 'hand blower', 'loudspeaker']
# Filename n03761084_microwave.JPEG: predictions ['microwave', 'rotisserie', 'dishwasher']
# Filename n03769881_minibus.JPEG: predictions ['minibus', 'minivan', 'recreational vehicle']
# Filename n03770439_miniskirt.JPEG: predictions ['miniskirt', 'television', 'maillot']
# Filename n03773504_missile.JPEG: predictions ['missile', 'projectile', 'aircraft carrier']
# Filename n03775071_mitten.JPEG: predictions ['mitten', 'wool', 'stole']
# Filename n03775546_mixing_bowl.JPEG: predictions ['Granny Smith', 'mixing bowl', 'soup bowl']
# Filename n03777568_Model_T.JPEG: predictions ['Model T', 'grille', 'pickup']
# Filename n03777754_modem.JPEG: predictions ['notebook', 'hand-held computer', 'modem']
# Filename n03781244_monastery.JPEG: predictions ['monastery', 'palace', 'castle']
# Filename n03785016_moped.JPEG: predictions ['moped', 'motor scooter', 'restaurant']
# Filename n03786901_mortar.JPEG: predictions ['mortar', 'sea cucumber', 'nail']
# Filename n03787032_mortarboard.JPEG: predictions ['mortarboard', 'academic gown', 'feather boa']
# Filename n03788365_mosquito_net.JPEG: predictions ['mosquito net', 'four-poster', 'window screen']
# Filename n03791053_motor_scooter.JPEG: predictions ['motor scooter', 'moped', 'crash helmet']
# Filename n03792782_mountain_bike.JPEG: predictions ['mountain bike', 'bicycle-built-for-two', 'sleeping bag']
# Filename n03793489_mouse.JPEG: predictions ['mouse', 'desktop computer', 'monitor']
# Filename n03794056_mousetrap.JPEG: predictions ['mousetrap', 'screwdriver', 'syringe']
# Filename n03796401_moving_van.JPEG: predictions ['moving van', 'trailer truck', 'mobile home']
# Filename n03814639_neck_brace.JPEG: predictions ['neck brace', 'water jug', 'sunglass']
# Filename n03814906_necklace.JPEG: predictions ['necklace', 'whistle', 'hook']
# Filename n03832673_notebook.JPEG: predictions ['notebook', 'laptop', 'iPod']
# Filename n03837869_obelisk.JPEG: predictions ['obelisk', 'cinema', 'pedestal']
# Filename n03838899_oboe.JPEG: predictions ['oboe', 'sax', 'flute']
# Filename n03841143_odometer.JPEG: predictions ['odometer', 'washer', 'oscilloscope']
# Filename n03843555_oil_filter.JPEG: predictions ['oil filter', 'disk brake', 'Dandie Dinmont']
# Filename n03854065_organ.JPEG: predictions ['organ', 'altar', 'church']
# Filename n03866082_overskirt.JPEG: predictions ['hoopskirt', 'overskirt', 'gown']
# Filename n03868242_oxcart.JPEG: predictions ['oxcart', 'ox', 'water buffalo']
# Filename n03868863_oxygen_mask.JPEG: predictions ['oxygen mask', 'lab coat', 'loupe']
# Filename n03874293_paddlewheel.JPEG: predictions ['paddlewheel', 'garbage truck', 'folding chair']
# Filename n03874599_padlock.JPEG: predictions ['padlock', 'chain', 'combination lock']
# Filename n03877472_pajama.JPEG: predictions ['pajama', 'maillot', 'maillot tank suit']
# Filename n03877845_palace.JPEG: predictions ['palace', 'castle', 'tile roof']
# Filename n03884397_panpipe.JPEG: predictions ['panpipe', 'black grouse', 'projectile']
# Filename n03888257_parachute.JPEG: predictions ['parachute', 'balloon', 'banana']
# Filename n03888605_parallel_bars.JPEG: predictions ['parallel bars', 'horizontal bar', 'balance beam']
# Filename n03891251_park_bench.JPEG: predictions ['park bench', 'lakeside', 'boathouse']
# Filename n03895866_passenger_car.JPEG: predictions ['passenger car', 'spotted salamander', 'steam locomotive']
# Filename n03899768_patio.JPEG: predictions ['patio', 'mobile home', 'monastery']
# Filename n03902125_pay-phone.JPEG: predictions ['pay-phone', 'dial telephone', 'refrigerator']
# Filename n03908618_pencil_box.JPEG: predictions ['pencil box', 'stopwatch', 'Loafer']
# Filename n03916031_perfume.JPEG: predictions ['perfume', 'lotion', 'wine bottle']
# Filename n03924679_photocopier.JPEG: predictions ['photocopier', 'printer', 'file']
# Filename n03929660_pick.JPEG: predictions ['pick', 'handkerchief', 'bow tie']
# Filename n03929855_pickelhaube.JPEG: predictions ['pickelhaube', 'military uniform', 'academic gown']
# Filename n03930630_pickup.JPEG: predictions ['pickup', 'beach wagon', 'jeep']
# Filename n03933933_pier.JPEG: predictions ['pier', 'steel arch bridge', 'fireboat']
# Filename n03935335_piggy_bank.JPEG: predictions ['piggy bank', 'hog', 'saltshaker']
# Filename n03938244_pillow.JPEG: predictions ['pillow', 'mailbag', 'purse']
# Filename n03942813_ping-pong_ball.JPEG: predictions ['ping-pong ball', 'ladle', 'measuring cup']
# ...
# Filename n04081281_restaurant.JPEG: predictions ['restaurant', 'grocery store', 'bakery']
# Filename n04086273_revolver.JPEG: predictions ['revolver', 'rifle', 'holster']
# Filename n04099969_rocking_chair.JPEG: predictions ['rocking chair', 'folding chair', 'dining table']
# Filename n04111531_rotisserie.JPEG: predictions ['rotisserie', 'microwave', 'refrigerator']
# Filename n04116512_rubber_eraser.JPEG: predictions ['rubber eraser', 'rule', 'ballpoint']
# Filename n04118776_rule.JPEG: predictions ['rule', 'wooden spoon', 'tick']
# Filename n04120489_running_shoe.JPEG: predictions ['running shoe', 'slug', 'sandal']
# Filename n04125021_safe.JPEG: predictions ['safe', 'espresso maker', 'combination lock']
# Filename n04131690_saltshaker.JPEG: predictions ['saltshaker', 'table lamp', 'vase']
# Filename n04133789_sandal.JPEG: predictions ['sandal', 'necklace', 'purse']
# Filename n04136333_sarong.JPEG: predictions ['sarong', 'brassiere', 'overskirt']
# Filename n04141327_scabbard.JPEG: predictions ['scabbard', 'letter opener', 'nail']
# Filename n04141975_scale.JPEG: predictions ['scale', 'barometer', 'stopwatch']
# Filename n04146614_school_bus.JPEG: predictions ['school bus', 'passenger car', 'minibus']
# Filename n04149813_scoreboard.JPEG: predictions ['scoreboard', 'barbershop', 'tobacco shop']
# Filename n04152593_screen.JPEG: predictions ['television', 'screen', 'monitor']
# Filename n04153751_screw.JPEG: predictions ['screw', 'nail', 'mortar']
# Filename n04162706_seat_belt.JPEG: predictions ['seat belt', 'car mirror', 'hammerhead']
# Filename n04179913_sewing_machine.JPEG: predictions ['sewing machine', 'chest', 'book jacket']
# Filename n04192698_shield.JPEG: predictions ['shield', 'banjo', 'bagel']
# Filename n04201297_shoji.JPEG: predictions ['shoji', 'sliding door', 'space heater']
# Filename n04204238_shopping_basket.JPEG: predictions ['shopping basket', 'hamper', 'shopping cart']
# Filename n04204347_shopping_cart.JPEG: predictions ['shopping cart', 'shopping basket', 'racket']
# Filename n04209133_shower_cap.JPEG: predictions ['shower cap', 'plastic bag', 'toilet tissue']
# Filename n04209239_shower_curtain.JPEG: predictions ['shower curtain', 'tiger cat', 'bathtub']
# Filename n04228054_ski.JPEG: predictions ['ski', 'parachute', 'ski mask']
# Filename n04235860_sleeping_bag.JPEG: predictions ['sleeping bag', 'mountain tent', 'quilt']
# Filename n04238763_slide_rule.JPEG: predictions ['slide rule', 'rule', 'barometer']
# Filename n04239074_sliding_door.JPEG: predictions ['sliding door', 'radiator', 'space heater']
# Filename n04251144_snorkel.JPEG: predictions ['snorkel', 'sunglasses', 'scuba diver']
# Filename n04252077_snowmobile.JPEG: predictions ['snowmobile', 'dogsled', 'bobsled']
# Filename n04252225_snowplow.JPEG: predictions ['snowplow', 'plow', 'tractor']
# Filename n04254777_sock.JPEG: predictions ['sock', 'Christmas stocking', 'cardigan']
# Filename n04258138_solar_dish.JPEG: predictions ['solar dish', 'tow truck', 'chainlink fence']
# Filename n04263257_soup_bowl.JPEG: predictions ['soup bowl', 'consomme', 'ladle']
# Filename n04264628_space_bar.JPEG: predictions ['space bar', 'typewriter keyboard', 'computer keyboard']
# Filename n04265275_space_heater.JPEG: predictions ['space heater', 'bassinet', 'cradle']
# Filename n04270147_spatula.JPEG: predictions ['spatula', 'wooden spoon', 'soup bowl']
# Filename n04273569_speedboat.JPEG: predictions ['speedboat', 'leatherback turtle', 'lifeboat']
# Filename n04275548_spider_web.JPEG: predictions ['spider web', 'garden spider', 'barn spider']
# Filename n04285008_sports_car.JPEG: predictions ['sports car', 'convertible', 'car wheel']
# Filename n04286575_spotlight.JPEG: predictions ['spotlight', 'chain saw', 'torch']
# Filename n04296562_stage.JPEG: predictions ['microphone', 'stage', 'maillot']
# Filename n04311004_steel_arch_bridge.JPEG: predictions ['steel arch bridge', 'pier', 'viaduct']
# Filename n04311174_steel_drum.JPEG: predictions ['steel drum', 'barrel', 'theater curtain']
# Filename n04317175_stethoscope.JPEG: predictions ['stethoscope', 'chain', 'hook']
# Filename n04326547_stone_wall.JPEG: predictions ['stone wall', 'megalith', 'promontory']
# Filename n04328186_stopwatch.JPEG: predictions ['stopwatch', 'pencil box', 'analog clock']
# Filename n04330267_stove.JPEG: predictions ['stove', 'fire screen', 'shoji']
# Filename n04335435_streetcar.JPEG: predictions ['streetcar', 'trolleybus', 'minibus']
# Filename n04336792_stretcher.JPEG: predictions ['stretcher', 'crash helmet', 'sunglasses']
# Filename n04344873_studio_couch.JPEG: predictions ['studio couch', 'four-poster', 'pool table']
# Filename n04347754_submarine.JPEG: predictions ['submarine', 'aircraft carrier', 'liner']
# Filename n04350905_suit.JPEG: predictions ['suit', 'Windsor tie', 'groom']
# Filename n04355338_sundial.JPEG: predictions ['sundial', 'rule', 'pole']
# Filename n04357314_sunscreen.JPEG: predictions ['hair spray', 'lotion', 'sunscreen']
# Filename n04366367_suspension_bridge.JPEG: predictions ['suspension bridge', 'maillot', 'bikini']
# Filename n04370456_sweatshirt.JPEG: predictions ['sweatshirt', 'sunglass', 'chain saw']
# Filename n04371430_swimming_trunks.JPEG: predictions ['swimming trunks', 'sunscreen', 'bikini']
# Filename n04376876_syringe.JPEG: predictions ['syringe', 'corkscrew', 'screwdriver']
# Filename n04380533_table_lamp.JPEG: predictions ['table lamp', 'lampshade', 'spotlight']
# Filename n04389033_tank.JPEG: predictions ['tank', 'amphibian', 'cannon']
# Filename n04398044_teapot.JPEG: predictions ['teapot', 'coffeepot', 'water jug']
# Filename n04399382_teddy.JPEG: predictions ['teddy', 'Band Aid', 'diaper']
# Filename n04404412_television.JPEG: predictions ['home theater', 'entertainment center', 'studio couch']
# Filename n04417672_thatch.JPEG: predictions ['thatch', 'military uniform', 'marimba']
# Filename n04418357_theater_curtain.JPEG: predictions ['theater curtain', 'stage', 'loudspeaker']
# Filename n04423845_thimble.JPEG: predictions ['thimble', 'cup', 'coffee mug']
# Filename n04429376_throne.JPEG: predictions ['throne', 'cradle', 'chest']
# Filename n04435653_tile_roof.JPEG: predictions ['tile roof', 'barn', 'birdhouse']
# Filename n04442312_toaster.JPEG: predictions ['toaster', 'soap dispenser', 'projector']
# Filename n04447861_toilet_seat.JPEG: predictions ['toilet seat', 'toilet tissue', 'plunger']
# Filename n04456115_torch.JPEG: predictions ['torch', 'caldron', 'Dutch oven']
# Filename n04458633_totem_pole.JPEG: predictions ['totem pole', 'pole', 'lakeside']
# Filename n04462240_toyshop.JPEG: predictions ['toyshop', 'comic book', 'confectionery']
# Filename n04465501_tractor.JPEG: predictions ['tractor', 'plow', 'harvester']
# Filename n04467665_trailer_truck.JPEG: predictions ['trailer truck', 'moving van', 'tow truck']
# Filename n04479046_trench_coat.JPEG: predictions ['trench coat', 'suit', 'velvet']
# Filename n04482393_tricycle.JPEG: predictions ['tricycle', 'jinrikisha', 'bicycle-built-for-two']
# Filename n04483307_trimaran.JPEG: predictions ['trimaran', 'catamaran', 'paddle']
# Filename n04486054_triumphal_arch.JPEG: predictions ['triumphal arch', 'suit', 'Loafer']
# Filename n04487081_trolleybus.JPEG: predictions ['trolleybus', 'passenger car', 'streetcar']
# Filename n04487394_trombone.JPEG: predictions ['trombone', 'cornet', 'bow tie']
# Filename n04501370_turnstile.JPEG: predictions ['turnstile', 'tripod', 'rule']
# Filename n04505470_typewriter_keyboard.JPEG: predictions ['typewriter keyboard', 'space bar', 'barber chair']
# Filename n04507155_umbrella.JPEG: predictions ['umbrella', 'bonnet', 'apron']
# Filename n04515003_upright.JPEG: predictions ['upright', 'organ', 'grand piano']
# Filename n04517823_vacuum.JPEG: predictions ['vacuum', 'suit', 'Loafer']
# Filename n04522168_vase.JPEG: predictions ['vase', 'confectionery', 'water jug']
# Filename n04525038_velvet.JPEG: predictions ['overskirt', 'trench coat', 'velvet']
# Filename n04525305_vending_machine.JPEG: predictions ['vending machine', 'pop bottle', 'jellyfish']
# Filename n04532106_vestment.JPEG: predictions ['lab coat', 'vestment', 'apron']
# Filename n04536866_violin.JPEG: predictions ['violin', 'cello', 'revolver']
# Filename n04540053_volleyball.JPEG: predictions ['volleyball', 'knee pad', 'Walker hound']
# Filename n04542943_waffle_iron.JPEG: predictions ['waffle iron', 'mixing bowl', 'measuring cup']
# Filename n04548362_wallet.JPEG: predictions ['wallet', 'envelope', 'pillow']
# Filename n04550184_wardrobe.JPEG: predictions ['wardrobe', 'medicine chest', 'chiffonier']
# Filename n04552348_warplane.JPEG: predictions ['warplane', 'wing', 'airliner']
# Filename n04557648_water_bottle.JPEG: predictions ['water bottle', 'water jug', 'soap dispenser']
# Filename n04560804_water_jug.JPEG: predictions ['water jug', 'espresso maker', 'Crock Pot']
# Filename n04579145_whiskey_jug.JPEG: predictions ['whiskey jug', 'milk can', 'water jug']
# Filename n04579432_whistle.JPEG: predictions ['whistle', 'hook', 'can opener']
# Filename n04584207_wig.JPEG: predictions ['wig', 'gown', 'maillot']
# Filename n04590129_window_shade.JPEG: predictions ['window shade', 'table lamp', 'radiator']
# Filename n04591157_Windsor_tie.JPEG: predictions ['Windsor tie', 'suit', 'wool']
# Filename n04591713_wine_bottle.JPEG: predictions ['wine bottle', 'red wine', 'shopping basket']
# Filename n04596742_wok.JPEG: predictions ['mashed potato', 'frying pan', 'plate']
# Filename n04597913_wooden_spoon.JPEG: predictions ['wooden spoon', 'vase', 'ladle']
# Filename n04599235_wool.JPEG: predictions ['wool', 'poncho', 'cardigan']
# Filename n04606251_wreck.JPEG: predictions ['wreck', 'breakwater', 'seashore']
# Filename n04612504_yawl.JPEG: predictions ['yawl', 'schooner', 'sandbar']
# Filename n04613696_yurt.JPEG: predictions ['yurt', 'quilt', 'studio couch']
# Filename n06596364_comic_book.JPEG: predictions ['bookshop', 'comic book', 'library']
# Filename n06785654_crossword_puzzle.JPEG: predictions ['crossword puzzle', 'paintbrush', 'rubber eraser']
# Filename n06794110_street_sign.JPEG: predictions ['street sign', 'worm fence', 'picket fence']
# Filename n07248320_book_jacket.JPEG: predictions ['book jacket', 'comic book', 'packet']
# Filename n07565083_menu.JPEG: predictions ['menu', 'comic book', 'vending machine']
# Filename n07579787_plate.JPEG: predictions ['plate', 'mashed potato', 'consomme']
# Filename n07584110_consomme.JPEG: predictions ['consomme', 'soup bowl', 'cup']
# Filename n07590611_hot_pot.JPEG: predictions ['hot pot', 'caldron', 'consomme']
# Filename n07613480_trifle.JPEG: predictions ['trifle', 'ice cream', 'bakery']
# Filename n07615774_ice_lolly.JPEG: predictions ['ice lolly', 'ice cream', 'banana']
# Filename n07684084_French_loaf.JPEG: predictions ['French loaf', 'bakery', 'pretzel']
# Filename n07693725_bagel.JPEG: predictions ['bagel', 'pizza', 'dough']
# Filename n07697313_cheeseburger.JPEG: predictions ['cheeseburger', 'bagel', 'modem']
# Filename n07697537_hotdog.JPEG: predictions ['hotdog', 'cheeseburger', 'corn']
# Filename n07711569_mashed_potato.JPEG: predictions ['mashed potato', 'meat loaf', 'plate']
# Filename n07714990_broccoli.JPEG: predictions ['broccoli', 'cauliflower', 'meat loaf']
# Filename n07715103_cauliflower.JPEG: predictions ['cauliflower', 'coral reef', 'bakery']
# Filename n07716358_zucchini.JPEG: predictions ['zucchini', 'cucumber', 'face powder']
# Filename n07717410_acorn_squash.JPEG: predictions ['acorn squash', 'spaghetti squash', 'butternut squash']
# Filename n07717556_butternut_squash.JPEG: predictions ['butternut squash', 'spaghetti squash', 'acorn squash']
# Filename n07718472_cucumber.JPEG: predictions ['cucumber', 'zucchini', 'spaghetti squash']
# Filename n07720875_bell_pepper.JPEG: predictions ['bell pepper', 'cucumber', 'grocery store']
# Filename n07730033_cardoon.JPEG: predictions ['cardoon', 'artichoke', 'bee']
# Filename n07734744_mushroom.JPEG: predictions ['mushroom', 'hen-of-the-woods', 'agaric']
# Filename n07745940_strawberry.JPEG: predictions ['strawberry', 'chocolate sauce', 'trifle']
# Filename n07747607_orange.JPEG: predictions ['orange', 'lemon', 'butternut squash']
# Filename n07749582_lemon.JPEG: predictions ['lemon', 'orange', 'grocery store']
# Filename n07753275_pineapple.JPEG: predictions ['pineapple', 'sandbar', 'seashore']
# Filename n07753592_banana.JPEG: predictions ['banana', 'greenhouse', 'ear']
# Filename n07754684_jackfruit.JPEG: predictions ['jackfruit', 'pretzel', 'bagel']
# Filename n07768694_pomegranate.JPEG: predictions ['pomegranate', 'guacamole', 'fig']
# Filename n07802026_hay.JPEG: predictions ['hay', 'barn', 'valley']
# Filename n07831146_carbonara.JPEG: predictions ['carbonara', 'potpie', 'hot pot']
# Filename n07860988_dough.JPEG: predictions ['dough', 'mixing bowl', 'strainer']
# Filename n07871810_meat_loaf.JPEG: predictions ['meat loaf', 'mashed potato', 'mixing bowl']
# Filename n07873807_pizza.JPEG: predictions ['pizza', 'bakery', 'dough']
# Filename n07880968_burrito.JPEG: predictions ['burrito', 'guacamole', 'plate']
# Filename n07892512_red_wine.JPEG: predictions ['wine bottle', 'red wine', 'corkscrew']
# Filename n07920052_espresso.JPEG: predictions ['espresso', 'espresso maker', 'beer glass']
# Filename n07932039_eggnog.JPEG: predictions ['eggnog', 'cocktail shaker', 'espresso']
# Filename n09193705_alp.JPEG: predictions ['valley', 'alp', 'cliff']
# Filename n09229709_bubble.JPEG: predictions ['bubble', 'goblet', 'beaker']
# Filename n09256479_coral_reef.JPEG: predictions ['coral reef', 'scuba diver', 'bubble']
# Filename n09288635_geyser.JPEG: predictions ['geyser', 'volcano', 'missile']
# Filename n09332890_lakeside.JPEG: predictions ['lakeside', 'sandbar', 'valley']
# Filename n09421951_sandbar.JPEG: predictions ['sandbar', 'swimming trunks', 'seashore']
# Filename n09428293_seashore.JPEG: predictions ['lakeside', 'breakwater', 'seashore']
# Filename n09468604_valley.JPEG: predictions ['valley', 'volcano', 'alp']
# Filename n09835506_ballplayer.JPEG: predictions ['ballplayer', 'scoreboard', 'military uniform']
# Filename n10148035_groom.JPEG: predictions ['groom', 'gown', 'theater curtain']
# Filename n10565667_scuba_diver.JPEG: predictions ['scuba diver', 'sea cucumber', 'eel']
# Filename n11939491_daisy.JPEG: predictions ['daisy', 'bee', 'fly']
# Filename n12057211_yellow_lady's_slipper.JPEG: predictions ["yellow lady's slipper", 'zucchini', 'pot']
# Filename n12144580_corn.JPEG: predictions ['corn', 'ear', 'broom']
# Filename n12620546_hip.JPEG: predictions ['hip', 'pomegranate', 'matchstick']
# Filename n12768682_buckeye.JPEG: predictions ['buckeye', 'wooden spoon', 'bolete']
# Filename n12985857_coral_fungus.JPEG: predictions ['coral fungus', 'hen-of-the-woods', 'mushroom']
# Filename n13037406_gyromitra.JPEG: predictions ['gyromitra', 'hen-of-the-woods', 'earthstar']
# Filename n13040303_stinkhorn.JPEG: predictions ['stinkhorn', 'earthstar', 'bolete']
# Filename n13044778_earthstar.JPEG: predictions ['earthstar', 'muzzle', 'mud turtle']
# Filename n13054560_bolete.JPEG: predictions ['bolete', 'acorn squash', 'cowboy hat']
# Filename n13133613_ear.JPEG: predictions ['corn', 'ear', 'black-and-tan coonhound']
# Filename n15075141_toilet_tissue.JPEG: predictions ['toilet tissue', 'paper towel', 'soap dispenser']
# Execution time:  41.97920203208923  seconds
# (raylet) [2023-06-21 14:18:55,838 E 84981 84981] (raylet) node_manager.cc:3069: 2 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 24fd95e201167276b700e6514649b829e3d3a3f702289e767c75903b, IP: 172.17.0.2) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.17.0.2`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
