# %% [markdown]
# ## Outline
#
# #### [Introduction](./nbconcepts/00_intro.ipynb)
# * Parallelism
# * Concurrency versus Parallelism
#
# #### [Tool 1: Parallel and Compiled Python](./nbtools/01_joblib.ipynb)
# * A First Program
# * Python parallel processes
# * Interpreted Languages
#     * the GIL
# * Compilation and just-in-time compilation
#     * Numba
#
#
# #### Concept 1: [Strong Scaling](./nbconcepts/01_strong_scaling.ipynb)
# * Amdahls Law
# * Speedup
# * Parallel Efficiency
#
# #### Concept 2: CPU Parallelism
#     * What is a CPU? (evolution of CPUs, motivation for parallelism, Moore's Law)
#     * Multicore
#         * Shared-memory
#     * ILP
#         * Pipelines
#         * Vectorization
#         * (XX) Other Sources (out-of-order execution, branch prediction, speculative execution)
# * Tools 2: OpenMP (https://hpc-tutorials.llnl.gov/openmp/)
#     * What is OpenMP (parallel C/Fortran on multicore, shared-memory architectures)
#     * Serial to Parallel Refactoring
#     * System overview
#         * Preprocessor
#         * Library
#         * Runtime
#     * Exmample #parallel directive
#         * Blocks and scoping
#     * Interacting with the environment
#         * openmp library calls
#         * (box) querying your processor
#     * fork/join parallelism
# * Concept 3: Factors Against Parallelism
#     * Interference
#     * Skew
#     * Startup costs
#     * Overlap
#     * top/htop processor utilization
# * Concept 4: Loop Parallelism
#     * Chunks
#     * Scoping and thread local variables
#     * Loop dependencies
#     * Loop fusion
#     * Loop fission
#     * Skew and dynamic scheduling (TODO)
# * Concept 5: Cache Hierarchy
#     * Row versus column order
#     * LM Bench
#     * memory efficiency TODO
#     * memory tool TODO
# * Concept 6: ILP
# * Tool 3: Vector Intrinsics
#   * TODO
# * Concept 7: NUMA
#   * NUMA architecture
#   * Demonstarting Example (TODO)
#   * (XX) Detecting and Programming to NUMA
#     * numactl and libnuma
#     * different between NUMA and hierarchy heterogeneity
# * Concept 8: Roofline

# %% [markdown]
# * Concept 9: Threads
#   * Threads vs. Processes
#   * Shared memory
# * Tool 4: Java Thread Programming
# * Concept 10: Thread Synchronization
# * Concept 11: Mutual Exclusion
#     * Bakery algorithm
#     * Fast Mutual Exclusion

# %% [markdown]
# * Concept 12: Distributed Memory Architectures
#     * Distributed Memory Programming
#         * Message Passing
#         * Remote Procedure Calls
#     * Client/Server and Service-Oriented Architectures
#     * Clusters and Supercomputers
#     * Clouds and Frameworks
# * Tool 5: MPI
#     * Send/Receive
#     * Deadlock
#     * Collective Operations
# * Concept 13: Data-Parallel Cloud Programming
#     * Map/Reduce: I/O Streaming
#     * In-Memory Computing
#     * Parallel Python
# * Concept 14: Distributed Arrays
# * Tool 6: Dask
# * Concept 15: Distrbuted Data-Frames
# * Concept 16: Resilient-Distributed Data Structures
#     * Lineage
#     * Recovery
#     * Checkpoints
# * Tool 7: Spark
# * Concept 14: Remote Functions
# * Tool 8: Ray
# * Concept 15: Actors
#   * TODO fix deadlock example or abandon

# %%
#### Concepts that didn't make it yet

Simultaneous multithreading
